# %% [markdown]
# # Exercise 1

# %% [markdown]
# Note that not every node in the array appears in the tree, because they are not valid

# %%
from IPython.display import Image
Image('https://walkccc.github.io/CLRS/img/10.4-1.png')

# %% [markdown]
# # Exercise 2

# %%
class Node:
    
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

# %%
seq = [18, 12, 10, 7, 4, 2, 21, 5]
node_list = [Node(x) for x in seq]

# %%
for i in range(len(seq)):
    try:
        node_list[i].left = node_list[2*i + 1]
        node_list[i].right = node_list[2*i + 2]
    except:
        pass

# %%
node_list[3].left = None

# %%
node_list[4].left = node_list[7]

# %%
node_1.left = node_2
node_1.right = node_3

# %%
node_2.left = node_4

# %%
node_2.right = None

# %%
def print_node(node):
    if node is None:
        pass
    else:
        print(node.val)
        print_node(node.left)
        print('ho')
        print_node(node.right)

# %%
print_node(node_list[0])
# Out:
# 18
# 12
# 7
# ho
# ho
# 4
# 5
# ho
# ho
# ho
# 10
# 2
# ho
# ho
# 21
# ho

# %% [markdown]
# # Exercise 3

# %%
def print_node_2(node):
    node_stack = []
    while True:
        while node is not None:
            print(node.val)
            node_stack.append(node)
            node = node.left
        if node_stack == []:
            break
        else:
            node = node_stack.pop().right

# %%
print_node_2(node_list[0])
# Out:
# 18
# 12
# 7
# 5
# 4
# 10
# 2
# 21
